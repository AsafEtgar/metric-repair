# %% [markdown]
# # Packages and Functions
#
# Thin loader. The library is split into two files:
# - [`graph_models.sage`](graph_models.sage) — random graph generators + `seed_all`
# - [`metric_repair.sage`](metric_repair.sage) — repair algorithms + their support
#
# The cell below loads both, so `%run Packages_and_Functions.ipynb` still pulls in everything.
# Edit the `.sage` files (plain text), not this notebook. The previous all-in-one notebook is kept
# as `Packages_and_Functions.BACKUP-2026-06-24.ipynb`.

# %%
load("graph_models.sage")
load("metric_repair.sage")
