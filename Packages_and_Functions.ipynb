# %% [markdown]
# # Packages and Functions
#
# This notebook is a **thin loader**. The actual library lives in
# [`packages_and_functions.sage`](packages_and_functions.sage); the cell below loads it into the
# current namespace.
#
# Other notebooks keep working unchanged via `%run Packages_and_Functions.ipynb` — that runs this
# notebook, which `load()`s the `.sage` file. Edit the library in the `.sage` file (plain text,
# diff-friendly), not here.
#
# The previous all-in-one notebook is preserved as `Packages_and_Functions.BACKUP-2026-06-24.ipynb`.

# %%
load("packages_and_functions.sage")
