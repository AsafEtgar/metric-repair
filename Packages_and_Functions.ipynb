# %% [markdown]
# # Packages and Functions
#
# Thin loader. The library is split into three files:
# - [`graph_models.sage`](graph_models.sage) — random graph generators + `seed_all`
# - [`metric_repair.sage`](metric_repair.sage) — repair algorithms + their support
# - [`metric_extras.sage`](metric_extras.sage) — auxiliary helpers not used by any repair algorithm
#   (diagnostics, triangle/cycle matrices, deprecated aliases); depends on `metric_repair.sage`
#
# The cell below loads all three, so `%run Packages_and_Functions.ipynb` still pulls in everything.
# Edit the `.sage` files (plain text), not this notebook. The previous all-in-one notebook is kept
# as `Packages_and_Functions.BACKUP-2026-06-24.ipynb`.

# %%
load("graph_models.sage")
load("metric_repair.sage")
load("metric_extras.sage")  # must come after metric_repair.sage
